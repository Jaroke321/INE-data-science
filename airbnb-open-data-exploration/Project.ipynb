# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/69450217-6cee2780-0d3b-11ea-947b-461ea407da85.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# ### Project
#
# # New York City Airbnb Open Data
#
# Let's put in practice the topics covered in the course and analyze Airbnb listings data.
#
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Read the `airbnb_data` dataset into a `airbnb_df` DataFrame variable.
#
# This data file includes all needed information to find out more about hosts and geographical availability.
#
# This public dataset is part of Airbnb, and the original source can be found on this [website](http://insideairbnb.com/).
#
# Here's a preview of that file:

# %%
# !head data/airbnb_data.csv
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# The column names are taken from the original documentation for this dataset.

# %%
# your code goes here
df = pd.read_csv('data/airbnb_data.csv')
df.head()
# Out:
#    listing_id                                      listing_name  host_id  \
# 0        2539                Clean & quiet apt home by the park     2787
# 1        2595                             Skylit Midtown Castle     2845
# 2        3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3        3831                   Cozy Entire Floor of Brownstone     4869
# 4        5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name     neighbourhood_group             lat_lon        room_type  \
# 0         John    Kensington, Brooklyn  40.64749;-73.97237     Private room
# 1     Jennifer      Midtown, Manhattan  40.75362;-73.98377  Entire home/apt
# 2    Elisabeth       Harlem, Manhattan   40.80902;-73.9419     Private room
# 3  LisaRoxanne  Clinton Hill, Brooklyn  40.68514;-73.95976  Entire home/apt
# 4        Laura  East Harlem, Manhattan  40.79851;-73.94399  Entire home/apt
#
#        price  minimum_nights  number_of_reviews last_review  \
# 0  $149,00.-               1                  9    19/10/18
# 1  $225,00.-               1                 45     21/5/19
# 2  $150,00.-               3                  0         NaN
# 3   $89,00.-               1                270      5/7/19
# 4   $80,00.-              10                  9    19/11/18
#
#    reviews_per_month  calculated_host_listings_count availability_365
# 0               0.21                               6              365
# 1               0.38                               2              355
# 2                NaN                               1              365
# 3               4.64                               1              194
# 4               0.10                               1                0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Setting `airbnb_data` index.
#
# Set the index of the DataFrame to the `listing_id` column.

# %%
# your code goes here
df.set_index('listing_id', inplace=True)
df.head()
# Out:
#                                                 listing_name  host_id  \
# listing_id
# 2539                      Clean & quiet apt home by the park     2787
# 2595                                   Skylit Midtown Castle     2845
# 3647                     THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3831                         Cozy Entire Floor of Brownstone     4869
# 5022        Entire Apt: Spacious Studio/Loft by central park     7192
#
#               host_name     neighbourhood_group             lat_lon  \
# listing_id
# 2539               John    Kensington, Brooklyn  40.64749;-73.97237
# 2595           Jennifer      Midtown, Manhattan  40.75362;-73.98377
# 3647          Elisabeth       Harlem, Manhattan   40.80902;-73.9419
# 3831        LisaRoxanne  Clinton Hill, Brooklyn  40.68514;-73.95976
# 5022              Laura  East Harlem, Manhattan  40.79851;-73.94399
#
#                   room_type      price  minimum_nights  number_of_reviews  \
# listing_id
# 2539           Private room  $149,00.-               1                  9
# 2595        Entire home/apt  $225,00.-               1                 45
# 3647           Private room  $150,00.-               3                  0
# 3831        Entire home/apt   $89,00.-               1                270
# 5022        Entire home/apt   $80,00.-              10                  9
#
#            last_review  reviews_per_month  calculated_host_listings_count  \
# listing_id
# 2539          19/10/18               0.21                               6
# 2595           21/5/19               0.38                               2
# 3647               NaN                NaN                               1
# 3831            5/7/19               4.64                               1
# 5022          19/11/18               0.10                               1
#
#            availability_365
# listing_id
# 2539                    365
# 2595                    355
# 3647                    365
# 3831                    194
# 5022                      0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Checking missing data
#
# We need to check if our `airbnb_data` has any null value.
#
# To do that, let's create a `percent_missing` Series containing the column names and the percent of missing values per column.

# %%
# your code goes here
percent_missing = (df.isna().sum() / df.shape[0]) * 100
percent_missing
# Out:
# listing_name                      0.000000
# host_id                           0.000000
# host_name                         0.094340
# neighbourhood_group               0.000000
# lat_lon                           0.000000
# room_type                         0.000000
# price                             0.000000
# minimum_nights                    0.000000
# number_of_reviews                 0.000000
# last_review                       4.056604
# reviews_per_month                 4.056604
# calculated_host_listings_count    0.000000
# availability_365                  0.000000
# dtype: float64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Dealing with `reviews_per_month` missing values
#
# Impute null values in the `reviews_per_month` column with a `0` value.

# %%
# your code goes here
df['reviews_per_month'] = df['reviews_per_month'].fillna(0)
df.head()
# Out:
#                                                 listing_name  host_id  \
# listing_id
# 2539                      Clean & quiet apt home by the park     2787
# 2595                                   Skylit Midtown Castle     2845
# 3647                     THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3831                         Cozy Entire Floor of Brownstone     4869
# 5022        Entire Apt: Spacious Studio/Loft by central park     7192
#
#               host_name     neighbourhood_group             lat_lon  \
# listing_id
# 2539               John    Kensington, Brooklyn  40.64749;-73.97237
# 2595           Jennifer      Midtown, Manhattan  40.75362;-73.98377
# 3647          Elisabeth       Harlem, Manhattan   40.80902;-73.9419
# 3831        LisaRoxanne  Clinton Hill, Brooklyn  40.68514;-73.95976
# 5022              Laura  East Harlem, Manhattan  40.79851;-73.94399
#
#                   room_type      price  minimum_nights  number_of_reviews  \
# listing_id
# 2539           Private room  $149,00.-               1                  9
# 2595        Entire home/apt  $225,00.-               1                 45
# 3647           Private room  $150,00.-               3                  0
# 3831        Entire home/apt   $89,00.-               1                270
# 5022        Entire home/apt   $80,00.-              10                  9
#
#            last_review  reviews_per_month  calculated_host_listings_count  \
# listing_id
# 2539          19/10/18               0.21                               6
# 2595           21/5/19               0.38                               2
# 3647               NaN               0.00                               1
# 3831            5/7/19               4.64                               1
# 5022          19/11/18               0.10                               1
#
#            availability_365
# listing_id
# 2539                    365
# 2595                    355
# 3647                    365
# 3831                    194
# 5022                      0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Dealing with `host_name` missing values
#
# Drop the rows where `host_name` has a missing value.

# %%
# your code goes here
df.dropna(axis=0, subset=['host_name'], inplace=True)
df.shape
# Out:
# (1059, 13)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Dealing with `last_review` missing values
#
# Drop the rows where `last_review` has a missing value.

# %%
# your code goes here
df.dropna(subset=['last_review'], inplace=True)
df.head()
# Out:
#                                                 listing_name  host_id  \
# listing_id
# 2539                      Clean & quiet apt home by the park     2787
# 2595                                   Skylit Midtown Castle     2845
# 3831                         Cozy Entire Floor of Brownstone     4869
# 5022        Entire Apt: Spacious Studio/Loft by central park     7192
# 5099               Large Cozy 1 BR Apartment In Midtown East     7322
#
#               host_name     neighbourhood_group             lat_lon  \
# listing_id
# 2539               John    Kensington, Brooklyn  40.64749;-73.97237
# 2595           Jennifer      Midtown, Manhattan  40.75362;-73.98377
# 3831        LisaRoxanne  Clinton Hill, Brooklyn  40.68514;-73.95976
# 5022              Laura  East Harlem, Manhattan  40.79851;-73.94399
# 5099              Chris  Murray Hill, Manhattan    40.74767;-73.975
#
#                   room_type      price  minimum_nights  number_of_reviews  \
# listing_id
# 2539           Private room  $149,00.-               1                  9
# 2595        Entire home/apt  $225,00.-               1                 45
# 3831        Entire home/apt   $89,00.-               1                270
# 5022        Entire home/apt   $80,00.-              10                  9
# 5099        Entire home/apt  $200,00.-               3                 74
#
#            last_review  reviews_per_month  calculated_host_listings_count  \
# listing_id
# 2539          19/10/18               0.21                               6
# 2595           21/5/19               0.38                               2
# 3831            5/7/19               4.64                               1
# 5022          19/11/18               0.10                               1
# 5099           22/6/19               0.59                               1
#
#            availability_365
# listing_id
# 2539                    365
# 2595                    355
# 3831                    194
# 5022                      0
# 5099                    129

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Dealing with `host_id` invalid values
#
# Drop the rows where `host_id` has a `0` value.

# %%
# your code goes here
df = df.loc[df['host_id'] != 0]
df.shape
# Out:
# (1003, 13)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Now cast this `last_review` column to `datetime`

# %%
# your code goes here
df['last_review'] = pd.to_datetime(df['last_review'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1003 entries, 2539 to 442649
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   listing_name                    1003 non-null   object
#  1   host_id                         1003 non-null   int64
#  2   host_name                       1003 non-null   object
#  3   neighbourhood_group             1003 non-null   object
#  4   lat_lon                         1003 non-null   object
#  5   room_type                       1003 non-null   object
#  6   price                           1003 non-null   object
#  7   minimum_nights                  1003 non-null   int64
#  8   number_of_reviews               1003 non-null   int64
#  9   last_review                     1003 non-null   datetime64[ns]
#  10  reviews_per_month               1003 non-null   float64
#  11  calculated_host_listings_count  1003 non-null   int64
#  12  availability_365                1003 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(7)
# memory usage: 109.7+ KB

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Duplicated listings
#
# Many listings could be duplicated. Drop all the entries that have the same `listing_name`, `price` and `room_type`. Keep just the last entry.

# %%
# your code goes here
df = df.loc[(df.duplicated(subset=['listing_name', 'price', 'room_type'], keep='last') == False)]
df.shape
# Out:
# (983, 13)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Invalid `price`
#
# Check the `price`. It should be a numeric type column.
#
# - Remove the `$`, `.` and `-` characters.
# - Replace `,` with a `.` character.
# - Cast the column to `float` dtype.

# %%
# your code goes here
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].str.replace('.', '')
df['price'] = df['price'].str.replace('-', '')
df['price'] = df['price'].str.replace(',', '.')
df['price'] = df['price'] = df['price'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 983 entries, 2539 to 442649
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   listing_name                    983 non-null    object
#  1   host_id                         983 non-null    int64
#  2   host_name                       983 non-null    object
#  3   neighbourhood_group             983 non-null    object
#  4   lat_lon                         983 non-null    object
#  5   room_type                       983 non-null    object
#  6   price                           983 non-null    float64
#  7   minimum_nights                  983 non-null    int64
#  8   number_of_reviews               983 non-null    int64
#  9   last_review                     983 non-null    datetime64[ns]
#  10  reviews_per_month               983 non-null    float64
#  11  calculated_host_listings_count  983 non-null    int64
#  12  availability_365                983 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(6)
# memory usage: 107.5+ KB
# <ipython-input-12-b39b9e7635da>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('$', '')
# <ipython-input-12-b39b9e7635da>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('.', '')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Separating `neighbourhood_group` column
#
# Check the `neighbourhood_group` column. It should be divided into two different columns: `neighbourhood` and `borough`.
#
# After the split, drop the `neighbourhood_group` column.

# %%
# your code goes here
df['neighbourhood'] = df['neighbourhood_group'].str.split(',').map(lambda x: x[0])
df['borough'] = df['neighbourhood_group'].str.split(',').map(lambda x: x[1])
df.drop('neighbourhood_group', axis=1, inplace=True)
df.head()
# Out:
#                                                 listing_name  host_id  \
# listing_id
# 2539                      Clean & quiet apt home by the park     2787
# 2595                                   Skylit Midtown Castle     2845
# 3831                         Cozy Entire Floor of Brownstone     4869
# 5022        Entire Apt: Spacious Studio/Loft by central park     7192
# 5099               Large Cozy 1 BR Apartment In Midtown East     7322
#
#               host_name             lat_lon        room_type  price  \
# listing_id
# 2539               John  40.64749;-73.97237     Private room  149.0
# 2595           Jennifer  40.75362;-73.98377  Entire home/apt  225.0
# 3831        LisaRoxanne  40.68514;-73.95976  Entire home/apt   89.0
# 5022              Laura  40.79851;-73.94399  Entire home/apt   80.0
# 5099              Chris    40.74767;-73.975  Entire home/apt  200.0
#
#             minimum_nights  number_of_reviews last_review  reviews_per_month  \
# listing_id
# 2539                     1                  9  2018-10-19               0.21
# 2595                     1                 45  2019-05-21               0.38
# 3831                     1                270  2019-05-07               4.64
# 5022                    10                  9  2018-11-19               0.10
# 5099                     3                 74  2019-06-22               0.59
#
#             calculated_host_listings_count availability_365 neighbourhood  \
# listing_id
# 2539                                     6              365    Kensington
# 2595                                     2              355       Midtown
# 3831                                     1              194  Clinton Hill
# 5022                                     1                0   East Harlem
# 5099                                     1              129   Murray Hill
#
#                borough
# listing_id
# 2539          Brooklyn
# 2595         Manhattan
# 3831          Brooklyn
# 5022         Manhattan
# 5099         Manhattan

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Separating `lat_lon` column
#
# Create two new columns `latitude` and `longitude` containing the product of splitting the `lat_lon` column. Both new columns should be casted to `float` dtype.
#
# After the split, drop the `lat_lon` column.

# %%
# your code goes here
df[['latitude', 'longitude']] = df['lat_lon'].str.split(';', expand=True).astype(float)
df.drop('lat_lon', axis=1, inplace=True)
df.head()
# Out:
#                                                 listing_name  host_id  \
# listing_id
# 2539                      Clean & quiet apt home by the park     2787
# 2595                                   Skylit Midtown Castle     2845
# 3831                         Cozy Entire Floor of Brownstone     4869
# 5022        Entire Apt: Spacious Studio/Loft by central park     7192
# 5099               Large Cozy 1 BR Apartment In Midtown East     7322
#
#               host_name        room_type  price  minimum_nights  \
# listing_id
# 2539               John     Private room  149.0               1
# 2595           Jennifer  Entire home/apt  225.0               1
# 3831        LisaRoxanne  Entire home/apt   89.0               1
# 5022              Laura  Entire home/apt   80.0              10
# 5099              Chris  Entire home/apt  200.0               3
#
#             number_of_reviews last_review  reviews_per_month  \
# listing_id
# 2539                        9  2018-10-19               0.21
# 2595                       45  2019-05-21               0.38
# 3831                      270  2019-05-07               4.64
# 5022                        9  2018-11-19               0.10
# 5099                       74  2019-06-22               0.59
#
#             calculated_host_listings_count availability_365 neighbourhood  \
# listing_id
# 2539                                     6              365    Kensington
# 2595                                     2              355       Midtown
# 3831                                     1              194  Clinton Hill
# 5022                                     1                0   East Harlem
# 5099                                     1              129   Murray Hill
#
#                borough  latitude  longitude
# listing_id
# 2539          Brooklyn  40.64749  -73.97237
# 2595         Manhattan  40.75362  -73.98377
# 3831          Brooklyn  40.68514  -73.95976
# 5022         Manhattan  40.79851  -73.94399
# 5099         Manhattan  40.74767  -73.97500

# %% [markdown]
# #### Visualizing points on a map
#
# Let's visualize your `airbnb_df` to confirm everything is in correct format so far.
#
# Execute the below code to visualize the `latitude` and `longitude` you just created.

# %%
longlat_min_max = (df.longitude.min(), df.longitude.max(), df.latitude.min(), df.latitude.max())

nyc = plt.imread('./data/nyc-map.png')

fig, ax = plt.subplots(figsize=(10,9))

ax.scatter(df.longitude, df.latitude, zorder=1, alpha=0.6, c='#fd5c63', s=10)
ax.set_title('Airbnb listing locations ')
ax.imshow(nyc, extent=longlat_min_max);

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Fixing `availability_365` values
#
# This columns should casted to numeric dtype, but it has many invalid string values, like `43+N524`, that should be coerced while casting.
#
# Also we can see many values out of domain, let's fix them:
# - Negative numbers, that should be converted to positive.
# - Numbers above 365, that should be dropped.

# %%
df['availability_365'].unique()
# Out:
# array(['365', '355', '194', '0', '129', '220', '188', '6', '39', '314',
#        '46', '321', '12', '21', '347', '364', '304', '233', '85', '75',
#        '311', '67', '255', '284', '359', '269', '340', '22', '96', '345',
#        '273', '3454', '95', '215', '265', '192', '251', '302', '140',
#        '234', '257', '30', '301', '294', '320', '154', '5234', '180',
#        '231', '297', '292', '191', '72', '362', '336', '116', '88', '224',
#        '322', '324', '132', '295', '238', '209', '328', '7', '272', '26',
#        '288', '317', '207', '185', '158', '9', '198', '219', '342', '312',
#        '243', '152', '137', '222', '346', '208', '279', '250', '164',
#        '298', '260', '107', '199', '299', '20', '318', '216', '245',
#        '189', '307', '310', '213', '278', '16', '178', '275', '163', '34',
#        '280', '1', '170', '214', '248', '262', '339', '10', '290', '230',
#        '53', '126', '3', '37', '353', '177', '1111', '246', '225', '18',
#        '343', '326', '162', '240', '363', '247', '323', '125', '91',
#        '286', '60', '58', '351', '201', '232', '258', '341', '244', '329',
#        '253', '348', '-153', '2', '56', '68', '360', '76', '15', '226',
#        '11', '281', '287', '14', '86', '261', '-104', '331', '51', '254',
#        '263', '103', '42', '249', '325', '35', '203', '5', '276', '102',
#        '71', '-135', '78', '8', '182', '49', '156', '200', '106', '135',
#        '142', '179', '52', '237', '204', '181', '296', '335', '5445',
#        '274', '98', '157', '174', '223', '361', '283', '315', '36',
#        '3645', '316', '271', '139', '193', '136', '277', '221', '6344',
#        '264', '236', '309', '333', '89', '23', '218', '235', '645', '119',
#        '350', '161', '259', '27', '167', '358', '59', '337', '-344',
#        '43+N524', '25', '127', '303', '115', '268', '3549', '56+N544',
#        '44', '65', '43', '252', '4234', '38', '64', '111', '90', '338',
#        '31', '241', '285', '183', '84', '166', '28', '83', '305', '356',
#        '308', '229', '-64', '210', '153', '332', '120', '9999', '313',
#        '69', '293', '4', '300', '81', '-234', '40', '117', '-15', '144',
#        '41', '270', '306', '33', '50', '80', '97', '118', '134', '17',
#        '289', '2222', '121', '205', '74', '29', '109', '168', '242',
#        '352', '155', '291', '79', '2666', '101', '190', '327', '349',
#        '217', '171', '110', '87', '202', '70', '147', '169', '212', '122',
#        '330', '54', '196', '57', '73'], dtype=object)

# %%
# your code goes here
df['availability_365'] = pd.to_numeric(df['availability_365'], errors='coerce')
df.dropna(subset=['availability_365'])
df = df.loc[df['availability_365'] <= 365]
df.loc[df['availability_365'] < 0, 'availability_365'] *= -1
df['availability_365'].shape
# Out:
# (969,)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Most reviews
#
# Create a Series `most_reviews` containing the top 10 `host_name`s with the most total (sum) reviews per month accross all properties owned by that host.

# %%
# your code goes here
most_reviews = df[['host_name', 'reviews_per_month']].groupby('host_name').sum().sort_values('reviews_per_month', ascending=False).head(10)
most_reviews
# Out:
#            reviews_per_month
# host_name
# Jason                  17.43
# Mark                    9.12
# Daniel                  8.77
# Carol                   8.50
# Lissette                8.19
# Marylyn                 8.17
# Ben                     7.54
# Dennis                  7.46
# Waldemar                7.36
# Evelyn                  7.17

# %% [markdown]
# #### Visualizing most_reviews

# %%
most_reviews.plot.pie(y='reviews_per_month', figsize=(8, 8))

plt.title("Top 10 Most Reviews Per Month")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Most expensive listings
#
# Create a variable `expensive_listings_df` containing the top 100 most expensive per night listings. The most expensive should be at the top.

# %%
# your code goes here
expensive_listings_df = df.sort_values('price', ascending=False)[:100]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which neighbourhood has biggest amount of expensive listings?
#
# Using the `expensive_listings_df` listings count the occurrences of each `neighbourhood` they belong.

# %%
# your code goes here
expensive_listings_df['neighbourhood'].value_counts()
# Out:
# Williamsburg          9
# Chelsea               9
# Greenpoint            7
# Harlem                7
# West Village          7
# East Village          7
# Upper West Side       5
# Nolita                5
# Carroll Gardens       4
# Clinton Hill          4
# Hell's Kitchen        3
# Midtown               3
# Upper East Side       3
# Bedford-Stuyvesant    3
# South Slope           2
# SoHo                  2
# Lower East Side       2
# Boerum Hill           2
# Park Slope            2
# DUMBO                 1
# Financial District    1
# Chinatown             1
# Flatbush              1
# Middle Village        1
# Gowanus               1
# Gramercy              1
# Little Italy          1
# Prospect Heights      1
# Ridgewood             1
# Brooklyn Heights      1
# Greenwich Village     1
# Washington Heights    1
# Flatiron District     1
# Name: neighbourhood, dtype: int64

# %% [markdown]
# #### Visualizing neighbourhoods

# %%
expensive_listings_df['neighbourhood'].value_counts().plot(kind='bar', figsize=(10,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which neighbourhood has the most listings?
#
# Using all the listings from `airbnb_df` count how many listings each neighbourhood has. Keep just the top 10 neighbourhoods with the most listings.

# %%
# your code goes here
df['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          110
# Harlem                 74
# Bedford-Stuyvesant     72
# East Village           65
# Upper West Side        44
# Greenpoint             42
# West Village           33
# Crown Heights          32
# Hell's Kitchen         30
# Park Slope             27
# Name: neighbourhood, dtype: int64

# %% [markdown]
# #### Visualizing neighbourhoods

# %%
df['neighbourhood'].value_counts().head(10).plot(kind='bar', figsize=(10,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
